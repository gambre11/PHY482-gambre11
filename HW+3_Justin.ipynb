# %%
#this is the wrong equation based off of my unit analysis but here goes nothing
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
w=1
Bo=1
m=1
R=1
a=1
t=np.arange(0,3,.01)

# %%
V=[]

for i in t:
    V.append(np.e**(-w**2*Bo**2/m/R*(Bo*a*i**2+a**2/3*i**3)))
plt.plot(t,V)

# %%
V=[]
a=2
for i in t:
    V.append(np.e**(-w**2*Bo**2/m/R*(Bo*a*i**2+a**2/3*i**3)))
plt.plot(t,V)

# %%
V=[]
a=3
for i in t:
    V.append(np.e**(-w**2*Bo**2/m/R*(Bo*a*i**2+a**2/3*i**3)))
plt.plot(t,V)

# %%
V=[]
a=20
for i in t:
    V.append(np.e**(-w**2*Bo**2/m/R*(Bo*a*i**2+a**2/3*i**3)))
plt.plot(t,V)
